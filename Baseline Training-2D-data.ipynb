# %% [markdown]
# # Baseline
#
# This is to check the gphi model (and in the future gw) trained using baseline setup and the new 2D data fromat.

# %% [markdown]
# ## Ideal

# %% [markdown]
# ### GW

# %%
from OurTrainingTools2D import *

random_seed = torch.randint(0, 1339, (1,)).item()
torch.manual_seed(random_seed)

td = OurTrainingData(['/data3/WZ_new_project/h5/Ideal_Data/ChP_pt300_sm_1.h5'],
                     ['/data3/WZ_new_project/h5/Ideal_Data/ChP_pt300_gwm5e-2.h5',
                     '/data3/WZ_new_project/h5/Ideal_Data/ChP_pt300_gwm1e-1.h5',
                     '/data3/WZ_new_project/h5/Ideal_Data/ChP_pt300_gwm2e-1.h5',
                     '/data3/WZ_new_project/h5/Ideal_Data/ChP_pt300_gw5e-2.h5',
                     '/data3/WZ_new_project/h5/Ideal_Data/ChP_pt300_gw1e-1.h5',
                     '/data3/WZ_new_project/h5/Ideal_Data/ChP_pt300_gw2e-1.h5',],
                     process = 'W+Z', parameters =['Gphi[TeV**-2]', 'GW[TeV**-2]'], 
                     SMNLimits=int(3e6), BSMNLimits=int(5e5))

td.Data = td.Data[:, :7]
td.CurateAngles([3, 5])

Data, ParVal, Labels, Weights = td.Data, td.ParVal, td.Labels, td.Weights
Data, ParVal, Labels, Weights = Data.float(), ParVal.float(), Labels.float(), Weights.float()

ParVal = ParVal[:, 0]

MD = OurModel(AR=[9,32,32,32,32,1])
#MD.double()
MD.InitPreprocess(Data, ParVal)
OT = OurTrainer(NumEpochs = int(1e4))
#OT = OurTrainer(NumEpochs = int(1e1))
OT.SetSaveAfterEpochs([10,100,500]+list(range(1000, 11000, 1000)))

OT.Train(MD, Data = Data, Parameters = ParVal, Labels=Labels, Weights= Weights, bs = 100000,
        Name = 'ChPgwIdeal5e-2,1e-1,2e-1, (Baseline, Seed%d), '%(random_seed), Folder = os.getcwd()+'/TrainedModels/',
        WeightClipping=True, L1Max=1)
# Out:
# =========== Random Seed: 246 ===========
# Loading Data Files for Process: W+Z, with new physics Parameters: ['Gphi[TeV**-2]', 'GW[TeV**-2]']
# Only 1D Implemented in Training !
#
# Reading file .../data3/WZ_new_project/h5/Ideal_Data/ChP_pt300_gwm5e-2.h5
# ##### File Info:
# {Gphi[TeV**-2], GW[TeV**-2]} = {0., -0.05}[TeV**-2] data, Ideal Events.
# Event format: {{s, θ, θZ, ϕZ, θWrec, ϕWrec, PtZ}, weight}.
# Converted from /data3/WZ_new_project/dat/Ideal_Events/ChP_pt300_gwm5e-2.dat.gz
# Charge = 1 --- Process = W+Z
# #####
#
# Reading file .../data3/WZ_new_project/h5/Ideal_Data/ChP_pt300_gwm1e-1.h5
# ##### File Info:
# {Gphi[TeV**-2], GW[TeV**-2]} = {0., -0.1}[TeV**-2] data, Ideal Events.
# Event format: {{s, θ, θZ, ϕZ, θWrec, ϕWrec, PtZ}, weight}.
# Converted from /data3/WZ_new_project/dat/Ideal_Events/ChP_pt300_gwm1e-1.dat.gz
# Charge = 1 --- Process = W+Z
# #####
#
# Reading file .../data3/WZ_new_project/h5/Ideal_Data/ChP_pt300_gwm2e-1.h5
# ##### File Info:
# ...

# %%
from OurTrainingTools2D import *

random_seed = torch.randint(0, 1339, (1,)).item()
torch.manual_seed(random_seed)

td = OurTrainingData(['/data3/WZ_new_project/h5/Ideal_Data/ChM_pt300_sm_1.h5'],
                     ['/data3/WZ_new_project/h5/Ideal_Data/ChM_pt300_gwm5e-2.h5',
                     '/data3/WZ_new_project/h5/Ideal_Data/ChM_pt300_gwm1e-1.h5',
                     '/data3/WZ_new_project/h5/Ideal_Data/ChM_pt300_gwm2e-1.h5',
                     '/data3/WZ_new_project/h5/Ideal_Data/ChM_pt300_gw5e-2.h5',
                     '/data3/WZ_new_project/h5/Ideal_Data/ChM_pt300_gw1e-1.h5',
                     '/data3/WZ_new_project/h5/Ideal_Data/ChM_pt300_gw2e-1.h5',],
                     process = 'W-Z', parameters =['Gphi[TeV**-2]', 'GW[TeV**-2]'], 
                     SMNLimits=int(3e6), BSMNLimits=int(5e5))

td.Data = td.Data[:, :7]
td.CurateAngles([3, 5])

Data, ParVal, Labels, Weights = td.Data, td.ParVal, td.Labels, td.Weights
Data, ParVal, Labels, Weights = Data.float(), ParVal.float(), Labels.float(), Weights.float()

ParVal = ParVal[:, 0]

MD = OurModel(AR=[9,32,32,32,32,1])
#MD.double()
MD.InitPreprocess(Data, ParVal)
OT = OurTrainer(NumEpochs = int(1e4))
#OT = OurTrainer(NumEpochs = int(1e1))
OT.SetSaveAfterEpochs([10,100,500]+list(range(1000, 11000, 1000)))

OT.Train(MD, Data = Data, Parameters = ParVal, Labels=Labels, Weights= Weights, bs = 100000,
        Name = 'ChMgwIdeal5e-2,1e-1,2e-1, (Baseline, Seed%d), '%(random_seed), Folder = os.getcwd()+'/TrainedModels/',
        WeightClipping=True, L1Max=1)
# Out:
# Loading Data Files for Process: W-Z, with new physics Parameters: ['Gphi[TeV**-2]', 'GW[TeV**-2]']
# Only 1D Implemented in Training !
#
# Reading file .../data3/WZ_new_project/h5/Ideal_Data/ChM_pt300_gwm5e-2.h5
# ##### File Info:
# {Gphi[TeV**-2], GW[TeV**-2]} = {0., -0.05}[TeV**-2] data, Ideal Events.
# Event format: {{s, θ, θZ, ϕZ, θWrec, ϕWrec, PtZ}, weight}.
# Converted from /data3/WZ_new_project/dat/Ideal_Events/ChM_pt300_gwm5e-2.dat.gz
# Charge = -1 --- Process = W-Z
# #####
#
# Reading file .../data3/WZ_new_project/h5/Ideal_Data/ChM_pt300_gwm1e-1.h5
# ##### File Info:
# {Gphi[TeV**-2], GW[TeV**-2]} = {0., -0.1}[TeV**-2] data, Ideal Events.
# Event format: {{s, θ, θZ, ϕZ, θWrec, ϕWrec, PtZ}, weight}.
# Converted from /data3/WZ_new_project/dat/Ideal_Events/ChM_pt300_gwm1e-1.dat.gz
# Charge = -1 --- Process = W-Z
# #####
#
# Reading file .../data3/WZ_new_project/h5/Ideal_Data/ChM_pt300_gwm2e-1.h5
# ##### File Info:
# ...

# %% [markdown]
# ### Gphi

# %%
from OurTrainingTools2D import *

random_seed = torch.randint(0, 1339, (1,)).item()
torch.manual_seed(random_seed)

td = OurTrainingData(['/data3/WZ_new_project/h5/Ideal_Data/ChP_pt300_sm_1.h5'],
                     ['/data3/WZ_new_project/h5/Ideal_Data/ChP_pt300_gphi5e-2.h5',
                     '/data3/WZ_new_project/h5/Ideal_Data/ChP_pt300_gphi2e-1.h5',
                     '/data3/WZ_new_project/h5/Ideal_Data/ChP_pt300_gphi5e-1.h5',
                     '/data3/WZ_new_project/h5/Ideal_Data/ChP_pt300_gphim5e-2.h5',
                     '/data3/WZ_new_project/h5/Ideal_Data/ChP_pt300_gphim2e-1.h5',
                     '/data3/WZ_new_project/h5/Ideal_Data/ChP_pt300_gphim5e-1.h5',],
                     process = 'W+Z', parameters =['Gphi[TeV**-2]', 'GW[TeV**-2]'], 
                     SMNLimits=int(3e6), BSMNLimits=int(5e5))

td.Data = td.Data[:, :7]
td.CurateAngles([3, 5])

Data, ParVal, Labels, Weights = td.Data, td.ParVal, td.Labels, td.Weights
Data, ParVal, Labels, Weights = Data.float(), ParVal.float(), Labels.float(), Weights.float()

ParVal = ParVal[:, 0]

MD = OurModel(AR=[9,32,32,32,32,1])
#MD.double()
MD.InitPreprocess(Data, ParVal)
OT = OurTrainer(NumEpochs = int(1e4))
#OT = OurTrainer(NumEpochs = int(1e1))
OT.SetSaveAfterEpochs([10,100,500]+list(range(1000, 11000, 1000)))

OT.Train(MD, Data = Data, Parameters = ParVal, Labels=Labels, Weights= Weights, bs = 100000,
        Name = 'ChPgphiIdeal5e-2,2e-1,5e-1, (Baseline, Seed%d), '%(random_seed), Folder = os.getcwd()+'/TrainedModels/',
        WeightClipping=True, L1Max=1)
# Out:
# Loading Data Files for Process: W+Z, with new physics Parameters: ['Gphi[TeV**-2]', 'GW[TeV**-2]']
# Only 1D Implemented in Training !
#
# Reading file .../data3/WZ_new_project/h5/Ideal_Data/ChP_pt300_gphi5e-2.h5
# ##### File Info:
# {Gphi[TeV**-2], GW[TeV**-2]} = {0.05, 0.}[TeV**-2] data, Ideal Events.
# Event format: {{s, θ, θZ, ϕZ, θWrec, ϕWrec, PtZ}, weight}.
# Converted from /data3/WZ_new_project/dat/Ideal_Events/ChP_pt300_gphi5e-2.dat.gz
# Charge = 1 --- Process = W+Z
# #####
#
# Reading file .../data3/WZ_new_project/h5/Ideal_Data/ChP_pt300_gphi2e-1.h5
# ##### File Info:
# {Gphi[TeV**-2], GW[TeV**-2]} = {0.2, 0.}[TeV**-2] data, Ideal Events.
# Event format: {{s, θ, θZ, ϕZ, θWrec, ϕWrec, PtZ}, weight}.
# Converted from /data3/WZ_new_project/dat/Ideal_Events/ChP_pt300_gphi2e-1.dat.gz
# Charge = 1 --- Process = W+Z
# #####
#
# Reading file .../data3/WZ_new_project/h5/Ideal_Data/ChP_pt300_gphi5e-1.h5
# ##### File Info:
# ...

# %%
from OurTrainingTools2D import *

random_seed = torch.randint(0, 1339, (1,)).item()
torch.manual_seed(random_seed)

td = OurTrainingData(['/data3/WZ_new_project/h5/Ideal_Data/ChM_pt300_sm_1.h5'],
                     ['/data3/WZ_new_project/h5/Ideal_Data/ChM_pt300_gphi5e-2.h5',
                     '/data3/WZ_new_project/h5/Ideal_Data/ChM_pt300_gphi2e-1.h5',
                     '/data3/WZ_new_project/h5/Ideal_Data/ChM_pt300_gphi5e-1.h5',
                     '/data3/WZ_new_project/h5/Ideal_Data/ChM_pt300_gphim5e-2.h5',
                     '/data3/WZ_new_project/h5/Ideal_Data/ChM_pt300_gphim2e-1.h5',
                     '/data3/WZ_new_project/h5/Ideal_Data/ChM_pt300_gphim5e-1.h5',],
                     process = 'W-Z', parameters =['Gphi[TeV**-2]', 'GW[TeV**-2]'], 
                     SMNLimits=int(3e6), BSMNLimits=int(5e5))

td.Data = td.Data[:, :7]
td.CurateAngles([3, 5])

Data, ParVal, Labels, Weights = td.Data, td.ParVal, td.Labels, td.Weights
Data, ParVal, Labels, Weights = Data.float(), ParVal.float(), Labels.float(), Weights.float()

ParVal = ParVal[:, 0]

MD = OurModel(AR=[9,32,32,32,32,1])
#MD.double()
MD.InitPreprocess(Data, ParVal)
OT = OurTrainer(NumEpochs = int(1e4))
#OT = OurTrainer(NumEpochs = int(1e1))
OT.SetSaveAfterEpochs([10,100,500]+list(range(1000, 11000, 1000)))

OT.Train(MD, Data = Data, Parameters = ParVal, Labels=Labels, Weights= Weights, bs = 100000,
        Name = 'ChMgphiIdeal5e-2,2e-1,5e-1, (Baseline, Seed%d), '%(random_seed), Folder = os.getcwd()+'/TrainedModels/',
        WeightClipping=True, L1Max=1)
# Out:
# =========== Random Seed: 579 ===========
# Loading Data Files for Process: W-Z, with new physics Parameters: ['Gphi[TeV**-2]', 'GW[TeV**-2]']
# Only 1D Implemented in Training !
#
# Reading file .../data3/WZ_new_project/h5/Ideal_Data/ChM_pt300_gphi5e-2.h5
# ##### File Info:
# {Gphi[TeV**-2], GW[TeV**-2]} = {0.05, 0.}[TeV**-2] data, Ideal Events.
# Event format: {{s, θ, θZ, ϕZ, θWrec, ϕWrec, PtZ}, weight}.
# Converted from /data3/WZ_new_project/dat/Ideal_Events/ChM_pt300_gphi5e-2.dat.gz
# Charge = -1 --- Process = W-Z
# #####
#
# Reading file .../data3/WZ_new_project/h5/Ideal_Data/ChM_pt300_gphi2e-1.h5
# ##### File Info:
# {Gphi[TeV**-2], GW[TeV**-2]} = {0.2, 0.}[TeV**-2] data, Ideal Events.
# Event format: {{s, θ, θZ, ϕZ, θWrec, ϕWrec, PtZ}, weight}.
# Converted from /data3/WZ_new_project/dat/Ideal_Events/ChM_pt300_gphi2e-1.dat.gz
# Charge = -1 --- Process = W-Z
# #####
#
# Reading file .../data3/WZ_new_project/h5/Ideal_Data/ChM_pt300_gphi5e-1.h5
# ##### File Info:
# ...

# %% [markdown]
# ## Check

# %%
from OurTrainingTools2D import *

# %%
MD = OurModel(AR=[9,32,32,32,32,1])

MD.Load('ChMgphiIdeal5e-2,2e-1,5e-1, (Baseline, Seed999), Final', os.getcwd()+'/TrainedModels/')

MD = MD.cpu()

MD.Save('ChMgphi_2D_999', '/home/chen/Documents/')
# Out:
# Model successfully loaded.
# Path: /home/chen/Documents/ParametrizedClassifier/TrainedModels/ChMgphiIdeal5e-2,2e-1,5e-1, (Baseline, Seed999), Final.pth
# Model successfully saved.
# Path: /home/chen/Documents/ChMgphi_2D_999.pth

# %%
td = OurTrainingData(['/data3/WZ_new_project/h5/Ideal_Data/ChP_pt300_sm_2.h5'],
                     ['/data3/WZ_new_project/h5/Ideal_Data/ChP_pt300_gphi5e-3.h5',],
                     process = 'W+Z', parameters =['Gphi[TeV**-2]', 'GW[TeV**-2]'], 
                     SMNLimits=int(5e5), BSMNLimits=int(5e5))

td.Data = td.Data[:, :7]
td.CurateAngles([3, 5])

Data, ParVal, Labels, Weights = td.Data, td.ParVal, td.Labels, td.Weights
Data, ParVal, Labels, Weights = Data.float(), ParVal.float(), Labels.float(), Weights.float()

ParVal = ParVal[:, 0]
# Out:
# Loading Data Files for Process: W+Z, with new physics Parameters: ['Gphi[TeV**-2]', 'GW[TeV**-2]']
# Only 1D Implemented in Training !
#
# Reading file .../data3/WZ_new_project/h5/Ideal_Data/ChP_pt300_gphi5e-3.h5
# ##### File Info:
# {Gphi[TeV**-2], GW[TeV**-2]} = {0.005, 0.}[TeV**-2] data, Ideal Events.
# Event format: {{s, θ, θZ, ϕZ, θWrec, ϕWrec, PtZ}, weight}.
# Converted from /data3/WZ_new_project/dat/Ideal_Events/ChP_pt300_gphi5e-3.dat.gz
# Charge = 1 --- Process = W+Z
# #####
#
# Reading file .../data3/WZ_new_project/h5/Ideal_Data/ChP_pt300_sm_2.h5
# ##### File Info:
# SM = {0., 0.}[TeV**-2] data, Ideal Events.
# Event format: {{s, θ, θZ, ϕZ, θWrec, ϕWrec, PtZ}, weight}.
# Converted from /data3/WZ_new_project/dat/Ideal_Events/ChP_pt300_sm_2.dat.gz
# Charge = 1 --- Process = W+Z
# #####
#
# Loaded SM Files:
# ['Gphi[TeV**-2]', 'GW[TeV**-2]']           #Data    XS[pb](avg.w)
# ---------------------------------------  -------  ---------------
# ...

# %%
point = (Data[0]).reshape(1, -1).cpu()
pval = torch.Tensor([0.005, ]).reshape(1, 1)

y = MD.Forward(point, pval).detach()

log_ratio = np.log(y/(1.-y))

log_ratio
# Out:
# tensor([[0.1736]])

# %%
point = torch.Tensor([[ 6.5493e+05,  1.1994e+00,  1.4807e+00,  1.5080e+00,  3.7705e+02,
         -9.1637e-01, -9.3152e-01, -4.0034e-01,  3.6369e-01]])
pval = np.array([0.005,]).reshape(-1, 1)

# %%
MD.Save('new_gphi_cpu', '/home/chen/Documents/')
# Out:
# Model successfully saved.
# Path: /home/chen/Documents/new_gphi_cpu.pth

# %%
for p in MD.parameters():
    print(p)
# Out:
# Parameter containing:
# tensor([[ 0.2177,  0.4083,  0.2054,  0.3171, -0.0774, -0.1036,  0.3280, -0.0925,
#          -0.2877],
#         [-0.2949, -0.2547, -0.3472, -0.1645, -0.1337, -0.3922, -0.2386,  0.1772,
#           0.1330],
#         [-0.4256, -0.0137,  0.1228, -0.0717,  0.2183,  0.1634, -0.2425, -0.1156,
#          -0.1897],
#         [-0.4637, -0.1802,  0.0939,  0.0788,  0.4969,  0.0407,  0.2760,  0.1679,
#          -0.0425],
#         [ 0.1810, -0.3552, -0.1407, -0.3258, -0.3726,  0.1891,  0.0166,  0.0440,
#           0.1069],
#         [-0.2618,  0.4093, -0.0954, -0.0788, -0.3208, -0.0905,  0.1684,  0.0324,
#          -0.2183],
#         [-0.1938, -0.5702, -0.2325,  0.1313, -0.2375, -0.0176, -0.0052,  0.0196,
#           0.2031],
#         [ 0.2732,  0.2091, -0.3697, -0.2151,  0.1389, -0.2206,  0.1746,  0.0848,
#           0.0116],
#         [ 0.1535,  0.1941,  0.1770, -0.0661,  0.3360,  0.3105, -0.3325,  0.3184,
#           0.0223],
# ...

# %%
TestEstimator(MD, 0.005, '4e-3_out', title_message=', quadratic classifier', qc=True)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-45-80619795fe00> in <module>
# ----> 1 TestEstimator(MD, 0.005, '4e-3_out', title_message=', quadratic classifier', qc=True)
#
# <ipython-input-3-076c8c0d0390> in TestEstimator(estimator, gphival, gphival_name, withXS, title_message, qc)
#       2
#       3     #toy data file path
# ----> 4     f = h5py.File(os.getcwd()+'/toydata/gphi_toydata_test_%s.h5'%(gphival_name), 'r')
#       5
#       6     #parse data
#
# ~/anaconda3/lib/python3.7/site-packages/h5py/_hl/files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, **kwds)
#     392                 fid = make_fid(name, mode, userblock_size,
#     393                                fapl, fcpl=make_fcpl(track_order=track_order),
# --> 394                                swmr=swmr)
#     395
# ...
